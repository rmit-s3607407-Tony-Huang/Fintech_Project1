# %%
import yfinance as yf

# %%
GSPC = yf.Ticker("^GSPC")
print(GSPC)
# Out:
# yfinance.Ticker object <^GSPC>

# %%
GSPC.info
# Out:
# {'exchange': 'SNP',
#  'shortName': 'S&P 500',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'messageBoardId': 'finmb_INDEXGSPC',
#  'market': 'us_market',
#  'previousClose': 4455.48,
#  'regularMarketOpen': 4442.12,
#  'twoHundredDayAverage': 4264.8545,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 4457.3,
#  'navPrice': None,
#  'averageDailyVolume10Day': 3139406000,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 4455.48,
#  'fiftyDayAverage': 4464.575,
#  'trailingAnnualDividendRate': None,
#  'open': 4442.12,
#  'toCurrency': None,
#  'averageVolume10days': 3139406000,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 4436.19,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 2043570000,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 3075077460,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 4436.19,
#  'ask': 4480.7,
#  'ytdReturn': None,
#  'askSize': 0,
#  'volume': 2043570000,
#  'fiftyTwoWeekHigh': 4545.85,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 3233.94,
#  'bid': 4394.11,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 4457.3,
#  'regularMarketPrice': 4443.11,
#  'logo_url': ''}

# %%
SP500 = GSPC.history(interval="1d", start="2016-01-01", end="2021-09-28")
SP500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2015-12-31  2060.590088  2062.540039  2043.619995  2043.939941  2655330000
# 2016-01-04  2038.199951  2038.199951  1989.680054  2012.660034  4304880000
# 2016-01-05  2013.780029  2021.939941  2004.170044  2016.709961  3706620000
# 2016-01-06  2011.709961  2011.709961  1979.050049  1990.260010  4336660000
# 2016-01-07  1985.319946  1985.319946  1938.829956  1943.089966  5076590000
# ...                 ...          ...          ...          ...         ...
# 2021-09-21  4374.450195  4394.870117  4347.959961  4354.189941  3044300000
# 2021-09-22  4367.430176  4416.750000  4367.430176  4395.640137  3273670000
# 2021-09-23  4406.750000  4465.399902  4406.750000  4448.979980  2833290000
# 2021-09-24  4438.040039  4463.120117  4430.270020  4455.479980  2772090000
# 2021-09-27  4442.120117  4457.299805  4436.189941  4443.109863  3032870000
#
#             Dividends  Stock Splits
# Date
# 2015-12-31          0             0
# 2016-01-04          0             0
# 2016-01-05          0             0
# 2016-01-06          0             0
# 2016-01-07          0             0
# ...               ...           ...
# 2021-09-21          0             0
# 2021-09-22          0             0
# 2021-09-23          0             0
# 2021-09-24          0             0
# 2021-09-27          0             0
#
# [1445 rows x 7 columns]

# %%
SP500 = SP500.drop('Stock Splits', axis=1)

# %%
SP500 = SP500.drop('Dividends', axis=1)

# %%
SP500 = SP500.drop('Volume', axis=1)

# %%
SP500 = SP500.drop('2015-12-31', axis=0)

# %%
SP500.to_csv(r'C:\Users\Ashley\Desktop\SP500_Data.csv')
